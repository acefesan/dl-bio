# %%
# %env JAX_DISABLE_JIT=FALSE
# %env JAX_PLATFORMS=cuda,cpu
# Out:
# env: JAX_DISABLE_JIT=FALSE
# env: JAX_PLATFORMS=cuda,cpu

# %%
import dlfb
from dlfb.utils.display import display
import py3Dmol
import requests

# %%
import pandas as pd

df = pd.read_feather("../assets/proteins/datasets/cafa3_merged/cafa3_with_embeddings.feather")
